# %% [markdown]
# # Hands-on with Machine Learning

# %% [markdown]
# Import needed packages

# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# import the two mnist datasets as numpy arrays
#
# Remember to remove the labels from them an put them in their own array

# %%
# np.loadtxt('', delimiter=',', dtype=int)

# %% [markdown]
# Plot a digit to check if the data is valid

# %%
#plt.imshow()

# %% [markdown]
# Choose a classifier from [sklearn](https://scikit-learn.org/stable/supervised_learning.html)
#
# Don't user neural networks, we will come back to it.
#
# **Remember** some takes a long time execute and score.

# %%
# from sklearn import XXXXX
# classifier = XXXXX.YYYYY

# %% [markdown]
# Fit the training data with the fit method. Look at the documentation if there is a max_iter or alike to make sure it does not run for the next 100 hours.

# %% [markdown]
# Now score the result.

# %% [markdown]
# Also try to inspect a test image and plot the corrosponding image, to see if it looks like it.

# %%
#print(f"Predicted class {classifier.predict(np.expand_dims(x_test[0], axis=0))}, actual class {y_test[0]}")
# plot the x_test[0]
